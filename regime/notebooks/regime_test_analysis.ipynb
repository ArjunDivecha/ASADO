# %% [markdown]
# # Regime Conditioning Value Test
#
# Orchestrator: `regime/run_regime_test.py`. Full write-up: `regime/regime.md`.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
exec(open(ROOT / 'run_regime_test.py').read())

# %%
from pathlib import Path
display(Markdown((Path('..') / 'regime.md').read_text()))
